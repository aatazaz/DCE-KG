# %%
import os
sample_file = os.listdir("../data/raw")[0]  # pick first file
with open(f"../data/raw/{sample_file}", "r", encoding="utf-8") as f:
    content = f.read()
print(f"File: {sample_file}")
print(f"Length: {len(content)} characters")
print("First 500 characters:")
print(content[:500])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 import os
# ----> 2 sample_file = os.listdir("../data/raw")[0]  # pick first file
#       3 with open(f"../data/raw/{sample_file}", "r", encoding="utf-8") as f:
#       4     content = f.read()
#       5 print(f"File: {sample_file}")
#
# IndexError: list index out of range
